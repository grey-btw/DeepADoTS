# %% [markdown]
# <a href="https://colab.research.google.com/github/grey-btw/DeepADoTS/blob/master/DeepADoTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone git://github.com/KDD-OpenSource/DeepADoTS.git
# !pip3 install virtualenv
# !virtualenv venv -p /usr/bin/python3 
# !source venv/bin/activate
# Out:
# Cloning into 'DeepADoTS'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 1156 (delta 0), reused 0 (delta 0), pack-reused 1153
# Receiving objects: 100% (1156/1156), 3.67 MiB | 33.30 MiB/s, done.
# Resolving deltas: 100% (814/814), done.
# ...
#      |████████████████████████████████| 7.2MB 13.7MB/s
# ...
#      |████████████████████████████████| 337kB 57.7MB/s
# ...
# created virtual environment CPython3.7.10.final.0-64 in 766ms
#   creator CPython3Posix(dest=/content/venv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==21.0.1, setuptools==54.1.2, wheel==0.36.2
#   activators BashActivator,CShellActivator,FishActivator,PowerShellActivator,PythonActivator,XonshActivator

# %%
# !ls
# !pip install -r ./DeepADoTS/requirements.txt
# Out:
# DeepADoTS  sample_data	venv
# ...
#   Cloning https://github.com/thu-ml/zhusuan.git to /tmp/pip-req-build-asriifwr
#   Running command git clone -q https://github.com/thu-ml/zhusuan.git /tmp/pip-req-build-asriifwr
# ...
#   Cloning https://github.com/korepwx/tfsnippet.git (to revision ecc0b4d1e610cf8cfa8c236857a7dabee27d5543) to /tmp/pip-req-build-dxrczkc7
#   Running command git clone -q https://github.com/korepwx/tfsnippet.git /tmp/pip-req-build-dxrczkc7
#   Running command git checkout -q ecc0b4d1e610cf8cfa8c236857a7dabee27d5543
# ...
#   Cloning https://github.com/korepwx/donut.git to /tmp/pip-req-build-tw4puh1b
#   Running command git clone -q https://github.com/korepwx/donut.git /tmp/pip-req-build-tw4puh1b
# Obtaining agots from git+https://github.com/KDD-OpenSource/agots#egg=agots (from -r ./DeepADoTS/requirements.txt (line 2))
#   Cloning https://github.com/KDD-OpenSource/agots to ./src/agots
#   Running command git clone -q https://github.com/KDD-OpenSource/agots /content/src/agots
# ...

# %%
# !python3 ./DeepADoTS/main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# 2021-03-25 05:26:45 [WARNING] root: Determinant was negative! Clipping Eigenvalues to 0+epsilon from -1.289783000402167e-07
# 2021-03-25 05:26:45 [WARNING] root: Determinant was negative! Clipping Eigenvalues to 0+epsilon from -5.874955633089485e-08
# 100% 40/40 [00:08<00:00,  4.62it/s]
# 2021-03-25 05:26:45 [WARNING] root: Determinant was negative! Clipping Eigenvalues to 0+epsilon from -1.1383516351770595e-07
# 2021-03-25 05:26:45 [WARNING] root: Determinant was negative! Clipping Eigenvalues to 0+epsilon from -1.1383516351770595e-07
# 2021-03-25 05:26:45 [WARNING] root: Determinant was negative! Clipping Eigenvalues to 0+epsilon from -1.1383516351770595e-07
# 2021-03-25 05:26:45 [WARNING] root: Determinant was negative! Clipping Eigenvalues to 0+epsilon from -1.1383516351770595e-07
# 2021-03-25 05:26:45 [WARNING] root: Determinant was negative! Clipping Eigenvalues to 0+epsilon from -1.1383516351770595e-07
# ...
